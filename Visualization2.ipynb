# %%
import pandas as pd
import cufflinks as cf
import matplotlib.pyplot as plt
import numpy as np

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dataset = pd.read_csv("Ginger.csv")
dataset
# Out:
#             Date Unit  Minimum  Maximum  Average  Market
# 0     2013-06-16   Kg      140      150    145.0  Ginger
# 1     2013-06-17   Kg      140      150    145.0  Ginger
# 2     2013-06-18   Kg      140      150    145.0  Ginger
# 3     2013-06-19   Kg      140      150    145.0  Ginger
# 4     2013-06-20   Kg      140      150    145.0  Ginger
# ...          ...  ...      ...      ...      ...     ...
# 2746  2021-05-09   Kg       60       80     70.0  Ginger
# 2747  2021-05-10   Kg       70       80     75.0  Ginger
# 2748  2021-05-11   Kg       70       80     75.0  Ginger
# 2749  2021-05-12   Kg       90      100     95.0  Ginger
# 2750  2021-05-13   Kg       80       90     85.0  Ginger
#
# [2751 rows x 6 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2751 entries, 0 to 2750
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2751 non-null   object
#  1   Unit     2751 non-null   object
#  2   Minimum  2751 non-null   int64
#  3   Maximum  2751 non-null   int64
#  4   Average  2751 non-null   float64
#  5   Market   2751 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 129.1+ KB

# %%
dataset = pd.read_csv("Ginger.csv", index_col=0)
dataset
# Out:
#            Unit  Minimum  Maximum  Average  Market
# Date
# 2013-06-16   Kg      140      150    145.0  Ginger
# 2013-06-17   Kg      140      150    145.0  Ginger
# 2013-06-18   Kg      140      150    145.0  Ginger
# 2013-06-19   Kg      140      150    145.0  Ginger
# 2013-06-20   Kg      140      150    145.0  Ginger
# ...         ...      ...      ...      ...     ...
# 2021-05-09   Kg       60       80     70.0  Ginger
# 2021-05-10   Kg       70       80     75.0  Ginger
# 2021-05-11   Kg       70       80     75.0  Ginger
# 2021-05-12   Kg       90      100     95.0  Ginger
# 2021-05-13   Kg       80       90     85.0  Ginger
#
# [2751 rows x 5 columns]

# %%
dataset.loc["2013":, ("Minimum", "Maximum", "Average")].iplot()
